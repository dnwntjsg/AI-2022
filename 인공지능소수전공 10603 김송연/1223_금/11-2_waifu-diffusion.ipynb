# %%
# %%capture
# !pip install diffusers transformers

# %%
import torch
from torch import autocast
from diffusers import StableDiffusionPipeline

pipe = StableDiffusionPipeline.from_pretrained(
    'hakurei/waifu-diffusion',
    torch_dtype=torch.float32
).to('cuda')

# %%
prompt = "1girl, aqua eyes, baseball cap, blonde hair, closed mouth, earrings, green background, hat, hoop earrings, jewelry, looking at viewer, shirt, short hair, simple background, solo, upper body, yellow shirt"
image = pipe(prompt, guidance_scale=6).images[0]  
image.save("test.png")
display(image)
# Out:
#   0%|          | 0/50 [00:00<?, ?it/s]
# <PIL.Image.Image image mode=RGB size=512x512 at 0x7F2A0A241EB0>

# %%
prompt = "princess_peach, anime face, pink dress, blonde hair, female, by Artgerm, Portraits of European Women in the 20th Century"
image = pipe(prompt, guidance_scale=6).images[0]  
image.save("test.png")
display(image)
# Out:
#   0%|          | 0/50 [00:00<?, ?it/s]
# <PIL.Image.Image image mode=RGB size=512x512 at 0x7F2A0A251AF0>

# %%
# 아이유 사진
# !wget -O IU.jpg https://w.namu.la/s/59bbf73b123d0f9f693be3c3de9506b24a1f2a3067b4ffd0207a3a08eee32d750ebf1ca3e33084aa3bbcd6916bd0a8a187cc4556b87fa269c25f1a7ff3ea279f1e372d23aa0a6eee8d5932c70d5dac0ed89254ec4872009767c6db499dc6f5df367f38cdc8779ce83fb78fe2bfb11df2
# !wget -O girl.jpg https://upload.wikimedia.org/wikipedia/commons/thumb/d/d7/Meisje_met_de_parel.jpg/800px-Meisje_met_de_parel.jpg
# Out:
# --2022-12-23 12:21:30--  https://w.namu.la/s/59bbf73b123d0f9f693be3c3de9506b24a1f2a3067b4ffd0207a3a08eee32d750ebf1ca3e33084aa3bbcd6916bd0a8a187cc4556b87fa269c25f1a7ff3ea279f1e372d23aa0a6eee8d5932c70d5dac0ed89254ec4872009767c6db499dc6f5df367f38cdc8779ce83fb78fe2bfb11df2
# Resolving w.namu.la (w.namu.la)... 104.19.233.61, 104.19.234.61, 2606:4700::6813:e93d, ...
# Connecting to w.namu.la (w.namu.la)|104.19.233.61|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://w.namu.la/s/59bbf73b123d0f9f693be3c3de9506b24a1f2a3067b4ffd0207a3a08eee32d750ebf1ca3e33084aa3bbcd6916bd0a8a187cc4556b87fa269c25f1a7ff3ea279f8bd16fd4a922cc9c1b3d6cb8fb4fdf16ba8dcb4d396b1a8210d524b60dc4105a [following]
# --2022-12-23 12:21:30--  https://w.namu.la/s/59bbf73b123d0f9f693be3c3de9506b24a1f2a3067b4ffd0207a3a08eee32d750ebf1ca3e33084aa3bbcd6916bd0a8a187cc4556b87fa269c25f1a7ff3ea279f8bd16fd4a922cc9c1b3d6cb8fb4fdf16ba8dcb4d396b1a8210d524b60dc4105a
# ...

# %%
# del pipe
import torch
from diffusers import StableDiffusionImg2ImgPipeline

pipe = StableDiffusionImg2ImgPipeline.from_pretrained(
    'hakurei/waifu-diffusion',
    torch_dtype=torch.float32
).to('cuda')
# Out:
# Fetching 15 files:   0%|          | 0/15 [00:00<?, ?it/s]
# Cannot initialize model with low cpu memory usage because `accelerate` was not found in the environment. Defaulting to `low_cpu_mem_usage=False`. It is strongly recommended to install `accelerate` for faster and less memory-intense model loading. You can do so with:
# ```
# pip install accelerate
# ```
# .

# %%
from PIL import Image

prompt = "girl with a pearl earring, anime face"

init_image = Image.open("girl.jpg")
init_image = init_image.resize((512, 612))
image = pipe(prompt=prompt, init_image=init_image, strength=0.6, guidance_scale=7.5).images[0]
display(image)
# Out:
#   0%|          | 0/30 [00:00<?, ?it/s]
# <PIL.Image.Image image mode=RGB size=512x608 at 0x7F2A0C75CF70>

# %%
from PIL import Image

prompt = "korean female idol, looking at viewer"

init_image = Image.open("IU.jpg")
init_image = init_image.resize((512, 612))
image = pipe(prompt=prompt, init_image=init_image, strength=0.5, guidance_scale=7.5).images[0]
display(image)

# %%
# !wget -O biden.jpg http://image.newsis.com/2022/07/09/NISI20220709_0019006570_web.jpg
# Out:
# --2022-12-23 12:28:15--  http://image.newsis.com/2022/07/09/NISI20220709_0019006570_web.jpg
# Resolving image.newsis.com (image.newsis.com)... 183.111.45.69, 183.111.45.68
# Connecting to image.newsis.com (image.newsis.com)|183.111.45.69|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 91070 (89K) [image/jpeg]
# Saving to: ‘biden.jpg’
#
# biden.jpg           100%[===================>]  88.94K   118KB/s    in 0.8s
#
# 2022-12-23 12:28:17 (118 KB/s) - ‘biden.jpg’ saved [91070/91070]

# %%
from PIL import Image

prompt = "US president, young white man, blond hair, shouting at people, manga style"
init_image = Image.open("biden.jpg")

image = pipe(prompt=prompt, init_image=init_image, strength=1.0, guidance_scale=5.0).images[0]
display(image)
# Out:
#   0%|          | 0/50 [00:00<?, ?it/s]
# <PIL.Image.Image image mode=RGB size=704x448 at 0x7F2A0C6ADE50>

# %%
# !wget -O zelenski.jpg https://img.seoul.co.kr/img/upload/2022/03/15/SSI_20220315164705_O2.jpg
# Out:
# --2022-12-23 12:31:21--  https://img.seoul.co.kr/img/upload/2022/03/15/SSI_20220315164705_O2.jpg
# Resolving img.seoul.co.kr (img.seoul.co.kr)... 183.111.246.138
# Connecting to img.seoul.co.kr (img.seoul.co.kr)|183.111.246.138|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 126542 (124K) [image/jpeg]
# Saving to: ‘zelenski.jpg’
#
# zelenski.jpg        100%[===================>] 123.58K   218KB/s    in 0.6s
#
# 2022-12-23 12:31:22 (218 KB/s) - ‘zelenski.jpg’ saved [126542/126542]

# %%
from PIL import Image

prompt = "Eastern European man, large body, young, angry face, anime face, sitting in the office Ukrainian flag is hanging"
init_image = Image.open("zelenski.jpg")

image = pipe(prompt=prompt, init_image=init_image, strength=0.5, guidance_scale=5.0).images[0]
display(image)
# Out:
#   0%|          | 0/25 [00:00<?, ?it/s]
# <PIL.Image.Image image mode=RGB size=576x384 at 0x7F2A0C6ADD00>
