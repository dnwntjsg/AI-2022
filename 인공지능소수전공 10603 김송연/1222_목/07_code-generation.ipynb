# %%
# !nvidia-smi
# Out:
# Thu Dec 22 12:37:15 2022
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.32.03    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   58C    P0    27W /  70W |      0MiB / 15109MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %%
# !pip install transformers
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
from transformers import pipeline

# %%
#model = pipeline(
#    'text-generation',
#    model='Salesforce/codegen-350M-mono',
#    device='cuda:0'
#)

# %%
#def generate_source(prompt, **kwargs):
#  print(model(prompt, **kwargs)[0]['generated_text'])

# %%
#generate_source(
#    "//when button is clicked, a post request is sent to the server using axios",
#   max_new_tokens=512
#)

# %%
model = pipeline(
    'text-generation',
    model='EleutherAI/gpt-neo-1.3B',
    device='cuda:0'
)
# Out:
# Downloading:   0%|          | 0.00/200 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/798k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/456k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/90.0 [00:00<?, ?B/s]

# %%
model("def hello_world():\n", max_new_tokens=256)
# Out:
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# [{'generated_text': "def hello_world():\n    from google.protobuf import text_format, NestedMessage\n    try:\n        str = text_format.GoogleMessage.DESCRIPTOR\n    except AttributeError:\n        if isinstance(str, bytes):\n            # https://github.com/google/protobuf/issues/1563\n            str = str.decode(sys.stdout)\n        else:\n            # https://github.com/google/protobuf/issues/1563\n            str = str\n        str = str.decode(sys.stdout)\n    if len(str)!= len(NestedMessage.DESCRIPTOR):\n        raise Exception('got {0}!= {1}'.format(len(NestedMessage.DESCRIPTOR), len(str)))\n    #"}]
