# %%
# !pip install transformers
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 5.8 MB 28.2 MB/s
# ...
#      |████████████████████████████████| 182 kB 79.4 MB/s
# ...
#      |████████████████████████████████| 7.6 MB 62.8 MB/s
# ...

# %%
from transformers import pipeline

# %% [markdown]
# ## 텍스트 생성

# %%
model = pipeline(
    'text-generation',
    model='skt/kogpt2-base-v2',
    device='cuda:0'
)
# Out:
# Downloading:   0%|          | 0.00/1.00k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/513M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/2.83M [00:00<?, ?B/s]
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.

# %%
model("아돌프 히틀러는", max_length=50, repetition_penalty=1.5, top_p=0.5, temperature=0.1)
# Out:
# [{'generated_text': '아돌프 히틀러는 히틀러를 \'위대한 장군\'으로 칭송했다.\n그러나 그는 히틀러의 나치즘에 대해 "그들은 단지 그들에 대한 증오심을 가지고 있는 것"이라며 "나는 그가 어떤 종류의 독재자였는지 알지 못한다"고 말했다.\n그는 또 자신이 독일'}]

# %% [markdown]
# ## 번역

# %%
ko2en_model = pipeline(
    'text2text-generation',
    model='QuoQA-NLP/KE-T5-Ko2En-Base'
)
en2ko_model = pipeline(
    'text2text-generation',
    model='QuoQA-NLP/KE-T5-En2Ko-Base'
)
# Out:
# Downloading:   0%|          | 0.00/731 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/990M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/2.01k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.47M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/4.61M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.79k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/725 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/990M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/2.01k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.47M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/4.61M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.79k [00:00<?, ?B/s]

# %%
ko2en_model("요즘 날씨가 너무 좋죠?")
# Out:
# [{'generated_text': 'Is the weather so good these days?'}]

# %%
ko2en_model("성탄절이라는 단어는 일반적으로 성스러운 사람의 탄생을 축하하는 명절이라는 의미이다.")
# Out:
# [{'generated_text': 'The word Christmas generally means a holiday to celebrate the birth of a saint.'}]

# %%
ko2en_model("앙 모띠")
# Out:
# [{'generated_text': 'Ang Motai is an nudice.'}]

# %%
en2ko_model('The word Christmas generally means a holiday to celebrate the birth of a saint, and in Christianity.', max_length=64, num_beams=4)
# Out:
# [{'generated_text': '크리스마스라는 단어는 일반적으로 성도의 탄생을 축하하는 명절, 기독교에서는 성탄절을 의미한다.'}]

# %%
en2ko_model("It seems that hanji clothing is here to stay")
# Out:
# [{'generated_text': '요추는 요추와 요추를 같이 한다.'}]

# %% [markdown]
# ## 요약

# %%
model = pipeline(
    'text2text-generation',
    model='gogamza/kobart-summarization'
)
# Out:
# You passed along `num_labels=3` with an incompatible id to label map: {'0': 'NEGATIVE', '1': 'POSITIVE'}. The number of labels wil be overwritten to 2.
# You passed along `num_labels=3` with an incompatible id to label map: {'0': 'NEGATIVE', '1': 'POSITIVE'}. The number of labels wil be overwritten to 2.
# You passed along `num_labels=3` with an incompatible id to label map: {'0': 'NEGATIVE', '1': 'POSITIVE'}. The number of labels wil be overwritten to 2.
# You passed along `num_labels=3` with an incompatible id to label map: {'0': 'NEGATIVE', '1': 'POSITIVE'}. The number of labels wil be overwritten to 2.

# %%
model(
    """나치 독일은 이 추축국의 리더에 해당하는 나라였다. 1933년에 아돌프 히틀러가 수상에 취임한 이후 독일은 자국의 재군비에 제동을 거는 국제연맹을 탈퇴하며 노골적으로 재군비 준비를 하였고, 급기야 1936년 3월에 라인란트 재무장으로서 베르사유 조약 파기를 선언하며 재군비에 박차를 가했다. 사실 이 무렵까지 독일, 이탈리아, 일본의 3국은 적도 동맹도 아닌 미묘한 관계였다.

만주사변 이후 일본은 국제연맹의 질타를 받아 이미 1933년에 독일과 함께 국제연맹을 탈퇴한 나라였지만 문제는 이탈리아였다. 당시 이탈리아는 여전히 국제연맹에 잔류하면서 나름대로 국제 사회의 일원으로서 움직였다. 특히 베니토 무솔리니는 1930년대 중반까지만 하더라도 히틀러를 탐탁찮게 생각했으며, 히틀러가 오스트리아 병합을 시도하자 자국 안보에 위협이 된다고 판단하여 영국, 프랑스와 스트레사 체제를 결성하여 "만약 오스트리아 병합을 시도하면 전쟁도 불사할 것이다!"고 엄포를 놓으며 독일에 강경하게 대응했다. 아무리 반쪽짜리 유사 열강 이탈리아라지만 이제 막 재무장을 시작한 독일이 이탈리아에 덤벼들면 어떻게 될 지는 자명했고 결국 히틀러가 한발 물러나면서 전쟁은 피했다.

그리고 1939년에 독일은 이탈리아와 강철 조약을 맺으면서 다시 한 번 우의를 다졌다. 이후 독일과 이탈리아, 일본 이 3국은 소련에 대응하기 위한 군사 동맹을 구상했지만, 1939년 독소 불가침 조약이 체결되면서 이 계획은 무산되었는데 왜냐하면 독일이 소련과 서로 불가침 조약을 맺어 이 추축국들 사이에서 분란이 발생했기 때문이다. 독소 불가침 조약의 문제는 독일이 소련과 접촉하고 있다는 사실을 일본, 이탈리아에 통보하지 않았다는 데 있다. 독소 불가침 조약 방침을 사전에 통보하고 양해를 구한 것이 아니라 히틀러와 리벤트로프의 독단으로 스탈린과 접촉하고 조약을 맺어버렸으니, 일본과 이탈리아가 크게 당황했다.[3]

1939년에 독일이 폴란드를 침공하면서 제2차 세계 대전이 발발하고 프랑스가 독일에 점령당하자[4] 독일은 일본, 이탈리아와 1940년 9월 27일에 삼국 동맹 조약을 맺어 추축동맹을 공식적으로 결성했다.""",
    max_length=256,
    num_beams=4,
    repetition_penalty=15.0
)
# Out:
# [{'generated_text': '1933년에 아돌프 히틀러가 수상에 취임한 이후 독일은 자국의 재군비 준비를 하였고, 급기야 1936년 3월에 라인란트 재무장으로서 베르사유 조약 파기를 선언하며 재군비에 박차를 가했다.'}]

# %% [markdown]
# ## 스타일 변환

# %%
styles = ['문어체','구어체','안드로이드','아재','채팅',
    '초등학생','이모티콘','enfp','신사','할아버지','할머니','중학생',
    '왕','나루토','선비','소심한','번역기']

model = pipeline(
    'text2text-generation',
    model='heegyu/kobart-text-style-transfer'
)
# Out:
# Downloading:   0%|          | 0.00/1.45k [00:00<?, ?B/s]
# You passed along `num_labels=3` with an incompatible id to label map: {'0': 'NEGATIVE', '1': 'POSITIVE'}. The number of labels wil be overwritten to 2.
# You passed along `num_labels=3` with an incompatible id to label map: {'0': 'NEGATIVE', '1': 'POSITIVE'}. The number of labels wil be overwritten to 2.
# Downloading:   0%|          | 0.00/496M [00:00<?, ?B/s]
# You passed along `num_labels=3` with an incompatible id to label map: {'0': 'NEGATIVE', '1': 'POSITIVE'}. The number of labels wil be overwritten to 2.
# Downloading:   0%|          | 0.00/682k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/4.00 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/112 [00:00<?, ?B/s]
# You passed along `num_labels=3` with an incompatible id to label map: {'0': 'NEGATIVE', '1': 'POSITIVE'}. The number of labels wil be overwritten to 2.

# %%
def transfer_text_style(text, target_style, **kwargs):
  input = f"{target_style} 말투로 변환: {text}"
  out = model(input, max_length=65, **kwargs)
  print(text, target_style, out[0]['generated_text'], sep="->")

# %%
text = "아"
for style in styles:
  transfer_text_style(text, style);
# Out:
# 아->문어체->아뇨네요.
# 아->구어체->아,네.
# 아->안드로이드->부정.
# 아->아재->아유
# 아->채팅->아
# 아->초등학생->아
# 아->이모티콘->아 ! (★‿★)
# 아->enfp->아닝~
# 아->신사->아,,
# 아->할아버지->아녀구먼...
# 아->할머니->아녀
# 아->중학생->아
# 아->왕->아, 그렇소.
# 아->나루토->아냐깐!
# 아->선비->그렇소!
# 아->소심한->아 맞..
# 아->번역기->그런, 나는 그것을 희망.

# %% [markdown]
# ## 소설 작성

# %%
model=pipeline(
    'text-generation',
    model='ttop324/kogpt2novel',
    device='cuda:0'
)
# Out:
# Downloading:   0%|          | 0.00/1.11k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/513M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/227 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.52M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/110 [00:00<?, ?B/s]

# %%
model(
    '스탈린',
    max_length=256,
    do_sample=True
)
# Out:
# [{'generated_text': '스탈린에 대한 보상으로 이 게임은 끝날 것이 틀림없다. 만약 아영이가 그것을 증명한다면, 그녀를 향한 수많은 사람들의 손가락질로부터 도망치고 싶은 자들은 아무도 없을 것이다. 그리고 그녀도 그것이 가능해진다면 그렇게 생각하고 싶지 않을 것이고, 그런 생각은 지금 그녀의 머릿속에 가득 들어차 있었다. “...이번 주에 우리 집에 가서 얘기한 거 맞아?” 지은이는 한숨을 내쉬었다. “그렇구나~. 너도 알다시피...” 남자 앞에서 발가벗고 음란하게 몸을 흔들며 성욕을 풀 수 있는 건 다들 몇 번 까지는 겪어야 될 일이었다. 하지만 그 모든 것들에 대해, 우리는 그저 여자애들을 상대로만 할 생각만이 지배적이었다고 그녀는 주장했다. 그것은 사실이었지만, 우리가 가타부타의 말도 안 되는 논리를 내세우는 동안 은연중에 우리의 마음을 어루렁어오게 만든 사람은 도무지 없었다. 오히려 지금의 상황에서는 더 이상 말할 필요조차 없다는 것은 당연한 결론이었고, 모두가 인정하는 바였다. 그녀가 말하는 것처럼, ‘나의 다짐’ 이란 단지 강요와 학대라는 단어가 아니라, ‘아침에 제모된 항문’을 의미하는 것인 만큼, 혹시 협박범의 말이 사실이더라도 어쩔 줄 모르고 있다는 의미까지 내포하고 있을까 봐 걱정이 앞섰기에 답답한 마음밖에 들지 않았다. “어제 네 시에 있었던 일이 기억 나요? 민준오'}]

# %%
model = pipeline(
    'text-generation',
    model='heegyu/kodialogpt-v1'
)
# Out:
# Downloading:   0%|          | 0.00/1.18k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/513M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/241 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/891k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/496k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/2.25M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/29.0 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/125 [00:00<?, ?B/s]

# %%
generation_args=dict(
    repetition_penalty=1.3,
    no_repeat_ngram_size=4,
    eos_token_id=375,
    max_new_tokens=32,
    do_sample=True,
    top_p=0.7,
    early_stopping=True
)

dialog="""

"""

model(
    dialog,
    **generation_args
)
# Out:
# [{'generated_text': '\n간부1: 지금 전세가 밀리고 있습니다.\n히틀러: 슈타인을 공격해. 그럼 해결될거야.\n간부2: 지금 슈타인에는 군대가 없습니다.\n히틀러: 그게 무슨 소리야!\n간부1: \n 0 : 우리회사랑 같은 군인이잖아! 나 지금 경찰한테 잡혀있어... 진짜 큰일이다'}]

# %%
# dialog = ""

# while True:
#   question = input("전송: ")
#   dialog += f"0: {question}\n1"
#   dialog=model(dialog, **generation_args)[0]['generated_text'] + "\n"

#   print(dialog)

# %%
model = pipeline(
    'text-generation',
    model='qiny17/lyrics-generator'
)
# Out:
# Downloading:   0%|          | 0.00/957 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/510M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/255 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/798k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/456k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/2.11M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/170 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/206 [00:00<?, ?B/s]

# %%
def generate_lyrics(prompt, **kwargs):
  print(model(prompt, **kwargs)[0]['generated_text'])

generate_lyrics(
    "The Demon has come to land,\n",
    max_length=666,
    do_sample=True
)
# Out:
# The Demon has come to land,
# The devil wants it more than I can handle
# I'm the one who has to protect him
# But the devil wants you more than you can handle
# I'm the one who has to protect ya
# But the devil wants you more than you can handle
#
# And I can't stand for him
# I got to put the dagger in the back, but
# Because there's somebody else
# That is helping him in the end
# But the devil wants you
# And I can't stand for Him
# I got to put the dagger in the back, but
# Because there's someone else
# That is helping Him in the end
# But the devil wants you
#
# The devil wants you, oh
# I'll wait, yeah
# And the devil wants you
# And all these people
# They're all going crazy, it's my fault
# You can do whatever you want, man
# But this devil wants you
# And I got to put the dagger in the back, oh
#
# And I can't stand it
# You can't stand It
# You can't stand It, yeah
